# %% [markdown]
# ## Identifying fields for processing the abstracts
#
# ### XML Field Path Extractor
#
# First extracting all unique XML tag paths from the abstracts XML files within the directory.

# %%
import os
import xml.etree.ElementTree as ET

def get_all_paths(root, current_path):
    paths = set()
    for elem in list(root):
        path = f"{current_path}/{elem.tag}" if current_path else elem.tag
        paths.add(path)
        paths.update(get_all_paths(elem, path))
    return paths

def extract_all_field_paths(directory_path):
    all_paths = set()
    for xml_file in os.listdir(directory_path):
        if xml_file.endswith('.xml'):
            file_path = os.path.join(directory_path, xml_file)
            tree = ET.parse(file_path)
            root = tree.getroot()
            file_paths = get_all_paths(root, '')
            all_paths.update(file_paths)
    return all_paths

directory_path = "../abstracts_2020/"
all_field_paths = extract_all_field_paths(directory_path)
sorted_field_paths = sorted(list(all_field_paths))
# sorted_field_paths # Uncomment if you want to see the list :)

# %% [markdown]
# ### Relevant fields for the model
# Here are the fields from the list that are likely to be most relevant:
#
# - 'Award/AbstractNarration': This contains the summary of the research which is central to understanding the topic of the paper.
# - 'Award/AwardTitle': This is likely to contain keywords or phrases indicative of the research topic.
# - 'Award/Organization/Directorate/LongName': The directorate name could indicate a broad area of research.
# - 'Award/Organization/Division/LongName': Similar to the directorate, the division name could indicate a more specific area of research within the broader directorate.
# - 'Award/ProgramElement/Text': If present, this might contain text about the program that funded the research, which could be related to the research topic.
# - 'Award/ProgramReference/Text': This could also provide context about the research topic based on the program reference.
#
# Other fields, particularly those containing names, addresses, numerical codes, and contact information, are less likely to be relevant for text-based topic clustering. They are typically used for administrative or identification purposes and do not contribute to the semantic content of the abstracts so for this case we will avoid them.
#
# 'Award/AwardTitle', 'Award/Organization/Directorate/LongName', 'Award/Organization/Division/LongName', 'Award/ProgramElement/Text', 'Award/ProgramReference/Text', 'Award/AbstractNarration'
#
# ### Preprocessing
# - First parse the files in order to get a dictionary. Here we can define wich fields will be returned for making possible to get as minimum as possible.
# - Second clean the text; by taking out the stop words (NLTK library) even if is needed to aggregate custom words that are unlikely to be useful; by lowering and keeping just characters between a-z and space; by finally lematizing (NTKL library).

# %%
import os
import re
import xml.etree.ElementTree as ET
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# Ensure that the necessary NLTK data is available (uncomment if necessary)
# nltk.download('wordnet')
# nltk.download('stopwords')

# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()


def parse_xml_for_fields(file_path: str, fields) -> dict:
    """
    Function to parse the XML for specified fields and return a dictionary
    with field names and their corresponding text
    """
    tree = ET.parse(file_path)
    root = tree.getroot()
    field_texts = {}
    for field in fields:
        elements = root.findall('.//' + field.replace('/', '/'))
        combined_text = " ".join([elem.text.strip() for elem in elements if elem.text is not None])
        field_texts[field] = combined_text if combined_text else "N/A"
    return field_texts


def clean_and_lemmatize_text(text: str) -> str:
    """Function to clean and lemmatize text"""
    stop_words_set = set(stopwords.words('english'))
    # stop_words.update(stopwords.words('spanish')) ## Use this line (or more like it) for other languages
    # additional_words = ['customword1', 'customword2', 'customword3'] # some words to avoid (if known)
    # stop_words.update(additional_words)
    text_lower = text.lower()
    text_cleaned = re.sub(r'[^a-z\s]', '', text_lower)
    words = text_cleaned.split()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words_set]
    return ' '.join(lemmatized_words)


def process_files(directory_path, fields):
    """
    Function to process all XML files in a directory and extract text from specified fields
    """
    xml_files = [os.path.join(directory_path, file) for file in os.listdir(directory_path) if file.endswith('.xml')]
    processed_data = []
    for file_path in xml_files:
        field_texts = parse_xml_for_fields(file_path, fields)
        for field, text in field_texts.items():
            field_texts[field] = clean_and_lemmatize_text(text)
        processed_data.append(field_texts)
    return processed_data

# %%
# Fields to be extracted from the XML file
fields = [
    'Award/AwardTitle',
    'Organization/Directorate/LongName',
    'Organization/Division/LongName',
    'ProgramElement/Text',
    'ProgramReference/Text',
    'AbstractNarration'
]

# Directory path where XML files are located
directory_path = "../abstracts_2020/"

# Process the XML files and extract the data
processed_data = process_files(directory_path, fields)

# %% [markdown]
# ### Getting some info about the processed files and words

# %%
print('files processed', len(processed_data))
# processed_data[0:4]

# Function to count the total words for each field
def count_total_words(processed_data, fields):
    word_counts = {field: 0 for field in fields}
    for data in processed_data:
        for field in fields:
            word_counts[field] += len(data[field].split()) if data[field] != "N/A" else 0
    return word_counts

# Count the words for each field in processed_data
word_counts = count_total_words(processed_data, fields)

# Print out the total words for each field
for field, count in word_counts.items():
    print(f"Total words in {field}: {count}")
# Out:
# files processed 13300
# Total words in Award/AwardTitle: 123835
# Total words in Organization/Directorate/LongName: 45857
# Total words in Organization/Division/LongName: 47358
# Total words in ProgramElement/Text: 43556
# Total words in ProgramReference/Text: 86616
# Total words in AbstractNarration: 3396389

# %% [markdown]
# ### Looking some of the data for specific abstracts

# %%
abstract_number_to_look = 42
for i in range(0,6):
    print(processed_data[abstract_number_to_look][fields[i]])
# Out:
# supporting early learning computational thinking using mixed reality technology
# directorate stem education
# division research learning
# itestinov tech exp stu teac
# covid impact existing activity broaden particip stem resrch ehr cl opportunity nsf
# project introduce young child computational thinking involves breaking complex problem manageable piece identifying step sequence solve problem generalizing solution solve similar problem problemsolving skill foundational cut across science technology engineering mathematics stem domain discipline project research develop innovative mixed reality mr learning environment combining visual display robot programmable movement child grade k program robot solve pathfinding problem hint obstacle problem scenario presented computer tablet project environment designed mainly oneonone use wirelessly flexibly either formal informal setting participating child teacher recruited partnership school community traditionally underrepresented stem ltbrgtltbrgtthe project design grounded research embodied cognition culturally responsive teaching child development humancomputer interaction develop experiential inclusive playful learning experience three main research question include design element critical effective mr environment childrens positive affect understanding sequence symbol evolve participate task time teacher need succeed facilitator promote computational thinking skill child engaged pathfinding task require guide robot arrive destination right path design learning environment research interwoven iterative cycle design testing development addition traditional data collection method sensor employed collection childrens movement data effectiveness environment learner understanding positive affect examined comparing intervention group control group teacher involved start incorporate practical insight feedback design project team implement teacher workshop year better understand need project disseminate project research finding resource widely researcher designer educator project funded innovative technology experience student teacher itest program support project build understanding practice program element context process contributing increasing student knowledge interest science technology engineering mathematics stem information communication technology ict careersltbrgtltbrgtthis award reflects nsf statutory mission deemed worthy support evaluation using foundation intellectual merit broader impact review criterion

# %% [markdown]
# ## EDA step to analyze word distribution and visualize data
#
# - Analyzing the distribution of words and phrases using a word frequency count.
# - Visualizing the data using word clouds and possibly bar charts to display the most common words.

# %%
from collections import Counter

# Function to calculate word frequency in given fields of a single processed_data object or all objects
def get_word_frequency(processed_data, fields_to_frequency_count, single_object_index=None):
    word_freq = Counter()
    
    # If a single_object_index is provided, work with a single object; otherwise, use all objects
    data_to_process = [processed_data[single_object_index]] if single_object_index is not None else processed_data
    
    for data in data_to_process:
        for field in fields_to_frequency_count:
            text = data[field] if field in data else ""
            word_freq.update(text.split())
    
    return word_freq

# %%
# Fields to calculate word frequencies
fields_to_frequency_count_total = ['Award/AwardTitle', 'Organization/Directorate/LongName',
                             'Organization/Division/LongName', 'ProgramElement/Text',
                             'ProgramReference/Text', 'AbstractNarration']

fields_to_frequency_count = ['Award/AwardTitle', 'Organization/Directorate/LongName',
                             'Organization/Division/LongName', 'ProgramElement/Text',
                             'ProgramReference/Text']

# To get word frequency for all objects
all_data_word_freq_all_fields = get_word_frequency(processed_data, fields_to_frequency_count_total)
all_data_word_freq_no_narration = get_word_frequency(processed_data, fields_to_frequency_count)

# %%
all_data_word_freq_no_narration
# Out:
# Counter({'research': 9008,
#          'science': 7235,
#          'division': 7081,
#          'direct': 7078,
#          'education': 5201,
#          'directorate': 5031,
#          'div': 3832,
#          'system': 3745,
#          'collaborative': 3728,
#          'mathematical': 3529,
#          'engineering': 3195,
#          'scie': 3159,
#          'exp': 3152,
#          'computer': 2943,
#          'physical': 2812,
#          're': 2557,
#          'covid': 2525,
#          'stem': 2505,
#          'undergraduate': 2493,
#          'scien': 2459,
#          'career': 2384,
#          'tech': 2332,
#          'info': 2282,
#          'biological': 2227,
#          'social': 2087,
#          'na': 2001,
#          'enginr': 1991,
#          'rapid': 1874,
#          'geosciences': 1823,
#          'prog': 1810,
#          'material': 1759,
#          'economic': 1702,
#          'comp': 1654,
#          'stim': 1644,
#          'sci': 1608,
#          'impact': 1569,
#          'learning': 1555,
#          'innovation': 1552,
#          'phase': 1528,
#          'graduate': 1483,
#          'network': 1392,
#          'sys': 1366,
#          'reu': 1342,
#          'sbir': 1311,
#          'project': 1311,
#          'involvement': 1285,
#          'dev': 1230,
#          'partnership': 1214,
#          'small': 1187,
#          'ugrd': 1148,
#          'information': 1141,
#          'behav': 1139,
#          'advanced': 1107,
#          'computing': 1086,
#          'careerfaculty': 1081,
#          'erly': 1081,
#          'eng': 1080,
#          'dir': 1068,
#          'program': 1034,
#          'supp': 1032,
#          'suppres': 1027,
#          'activity': 1026,
#          'translational': 1017,
#          'infrastructure': 996,
#          'technology': 941,
#          'dynamic': 924,
#          'civil': 906,
#          'undergrad': 906,
#          'foundation': 899,
#          'biology': 893,
#          'office': 875,
#          'eager': 869,
#          'physic': 862,
#          'earth': 840,
#          'chem': 794,
#          'minority': 777,
#          'data': 773,
#          'core': 736,
#          'ocean': 732,
#          'mechanical': 717,
#          'bioeng': 712,
#          'env': 712,
#          'transp': 712,
#          'computational': 699,
#          'coviddisproportionate': 695,
#          'impcts': 695,
#          'instindiv': 695,
#          'chemistry': 685,
#          'workshop': 674,
#          'conference': 669,
#          'manufact': 662,
#          'inn': 662,
#          'bio': 662,
#          'intelligent': 657,
#          'analysis': 637,
#          'environmental': 628,
#          'quantum': 621,
#          'intelligence': 618,
#          'cognitive': 607,
#          'theory': 606,
#          'communication': 596,
#          'secure': 589,
#          'software': 588,
#          'woman': 588,
#          'math': 585,
#          'behavioral': 571,
#          'manufacturing': 556,
#          'using': 554,
#          'community': 548,
#          'disabled': 546,
#          'nec': 543,
#          'special': 537,
#          'trustworthy': 534,
#          'cyberspace': 526,
#          'energy': 526,
#          'nano': 522,
#          'divn': 517,
#          'site': 512,
#          'development': 509,
#          'icorps': 507,
#          'process': 504,
#          'integrative': 498,
#          'nsf': 496,
#          'control': 495,
#          'molecular': 492,
#          'atmospheric': 488,
#          'opp': 477,
#          'fellowship': 476,
#          'support': 467,
#          'instrumentation': 465,
#          'marine': 461,
#          'center': 458,
#          'environment': 456,
#          'nanoscale': 449,
#          'cellular': 438,
#          'chemical': 437,
#          'understanding': 437,
#          'nonsolic': 436,
#          'awd': 436,
#          'cyberinfrastructure': 435,
#          'commun': 434,
#          'life': 434,
#          'oceanography': 433,
#          'machine': 431,
#          'change': 427,
#          'cyber': 424,
#          'model': 422,
#          'student': 420,
#          'integration': 420,
#          'design': 413,
#          'proposal': 412,
#          'satc': 405,
#          'electrical': 403,
#          'ai': 401,
#          'arctic': 400,
#          'ecosystem': 396,
#          'application': 394,
#          'initiative': 388,
#          'study': 378,
#          'biotechnology': 372,
#          'new': 370,
#          'robust': 369,
#          'postdoctoral': 364,
#          'artificial': 363,
#          'informatics': 361,
#          'modeling': 360,
#          'mathematics': 355,
#          'interaction': 353,
#          'global': 350,
#          'mechanism': 349,
#          'method': 349,
#          'organismal': 347,
#          'geospace': 345,
#          'iuse': 343,
#          'multidisciplinary': 334,
#          'ii': 332,
#          'human': 327,
#          'improv': 326,
#          'climate': 324,
#          'response': 322,
#          'ediuse': 321,
#          'epscor': 318,
#          'hardware': 314,
#          'smart': 312,
#          'experience': 309,
#          'interdisciplinary': 300,
#          'geophysics': 292,
#          'medium': 289,
#          'astronomy': 288,
#          'major': 287,
#          'polar': 285,
#          'oac': 285,
#          'equity': 277,
#          'rule': 277,
#          'existing': 276,
#          'plant': 274,
#          'health': 273,
#          'resource': 272,
#          'device': 269,
#          'high': 265,
#          'doctoral': 264,
#          'bioscience': 263,
#          'excellence': 259,
#          'approach': 259,
#          'astronomical': 252,
#          'matter': 252,
#          'grant': 251,
#          'assist': 251,
#          'workforce': 250,
#          'processing': 250,
#          'cns': 249,
#          'structure': 248,
#          'effect': 245,
#          'cofunding': 243,
#          'dissertation': 241,
#          'lia': 240,
#          'role': 240,
#          'robotics': 238,
#          'participation': 238,
#          'mechanic': 238,
#          'sensor': 237,
#          'novel': 237,
#          'urolunderstanding': 236,
#          'acad': 234,
#          'windus': 234,
#          'track': 233,
#          'algorithm': 232,
#          'genome': 232,
#          'nanomaterials': 232,
#          'enging': 231,
#          'deep': 230,
#          'national': 230,
#          'framework': 229,
#          'sttr': 229,
#          'complex': 228,
#          'resrch': 226,
#          'connected': 224,
#          'risk': 221,
#          'ecology': 219,
#          'institute': 219,
#          'college': 216,
#          'function': 216,
#          'behavior': 216,
#          'crossbio': 213,
#          'evolution': 212,
#          'early': 210,
#          'decision': 210,
#          'anthropology': 210,
#          'planning': 209,
#          'carbon': 207,
#          'siteres': 207,
#          'state': 206,
#          'faculty': 205,
#          'discovery': 204,
#          'universe': 204,
#          'university': 203,
#          'population': 203,
#          'broaden': 200,
#          'diversity': 197,
#          'geology': 197,
#          'structural': 196,
#          'rui': 195,
#          'water': 195,
#          'sustainable': 194,
#          'building': 194,
#          'platform': 193,
#          'disaster': 192,
#          'condensed': 189,
#          'transport': 188,
#          'instresearch': 188,
#          'edu': 188,
#          'circuit': 187,
#          'developing': 187,
#          'future': 187,
#          'comm': 186,
#          'economics': 186,
#          'synthetic': 183,
#          'synergy': 183,
#          'acquisition': 183,
#          'cell': 182,
#          'teacher': 182,
#          'international': 182,
#          'field': 181,
#          'emerging': 181,
#          'mri': 180,
#          'syst': 179,
#          'archaeology': 179,
#          'surface': 178,
#          'ac': 178,
#          'detection': 177,
#          'ant': 177,
#          'ecological': 176,
#          'pandemic': 175,
#          'via': 175,
#          'security': 175,
#          'management': 174,
#          'evolutionary': 173,
#          'broadening': 172,
#          'wireless': 171,
#          'integrated': 171,
#          'astrophysics': 168,
#          'hazard': 167,
#          'strategic': 167,
#          'solid': 167,
#          'advance': 166,
#          'digitization': 166,
#          'sustainability': 165,
#          'optimization': 165,
#          'diagnostics': 163,
#          'zone': 161,
#          'sensing': 160,
#          'service': 159,
#          'scale': 159,
#          'networking': 158,
#          'imaging': 158,
#          'particip': 157,
#          'cycle': 157,
#          'theoretical': 157,
#          'neural': 157,
#          'natural': 156,
#          'convergence': 155,
#          'across': 155,
#          'investigating': 155,
#          'scholarship': 154,
#          'polymer': 152,
#          'observational': 152,
#          'biodiversity': 152,
#          'storage': 152,
#          'tool': 150,
#          'adaptive': 150,
#          'term': 150,
#          'variability': 150,
#          'linguistics': 150,
#          'measurement': 149,
#          'resilience': 149,
#          'perception': 148,
#          'particle': 147,
#          'statistic': 146,
#          'scalable': 146,
#          'nsci': 146,
#          'initi': 145,
#          'grad': 144,
#          'com': 143,
#          'black': 142,
#          'prep': 142,
#          'space': 142,
#          'algebranumber': 142,
#          'theoryand': 142,
#          'apgenhan': 141,
#          'fy': 139,
#          'capacity': 139,
#          'futr': 138,
#          'geometry': 138,
#          'transformation': 137,
#          'clean': 137,
#          'biomechanics': 137,
#          'power': 136,
#          'metal': 136,
#          'outreach': 136,
#          'microbial': 135,
#          'nri': 135,
#          'suppl': 135,
#          'rsch': 135,
#          'action': 134,
#          'largescale': 134,
#          'applied': 134,
#          'training': 134,
#          'u': 133,
#          'spatial': 133,
#          'simulation': 133,
#          'improving': 132,
#          'genetic': 132,
#          'k': 131,
#          'facility': 131,
#          'large': 130,
#          'ecredu': 130,
#          'transmission': 130,
#          'testing': 129,
#          'collection': 129,
#          'ddri': 127,
#          'ed': 126,
#          'synthesis': 126,
#          'plasma': 126,
#          'investigation': 125,
#          'amadvanced': 125,
#          'dynamical': 124,
#          'biorelated': 124,
#          'critical': 124,
#          'teaching': 124,
#          'multiscale': 124,
#          'towards': 124,
#          'cultural': 124,
#          'car': 123,
#          'cyberhuman': 123,
#          'brain': 122,
#          'epmdelectrnphotonmagndevices': 122,
#          'antarctic': 122,
#          'experimental': 121,
#          'law': 121,
#          'reduction': 120,
#          'generation': 120,
#          'cognition': 120,
#          'efficient': 119,
#          'pro': 119,
#          'biomedical': 119,
#          'operation': 118,
#          'xccrosscutting': 118,
#          'award': 117,
#          'ret': 117,
#          'director': 116,
#          'use': 115,
#          'flow': 115,
#          'pathway': 114,
#          'cps': 114,
#          'mgmt': 114,
#          'sstemschlr': 113,
#          'engmath': 113,
#          'protein': 113,
#          'hcchumancentered': 113,
#          'group': 113,
#          'fwhtf': 112,
#          'wrk': 112,
#          'humtech': 112,
#          'frntr': 112,
#          'organic': 112,
#          'scc': 112,
#          'topology': 112,
#          'coop': 112,
#          'exploring': 112,
#          'ccf': 110,
#          'based': 110,
#          'formal': 110,
#          'proc': 110,
#          'sarscov': 109,
#          'optic': 109,
#          'school': 108,
#          'sbe': 108,
#          'photonics': 108,
#          'functional': 108,
#          'short': 107,
#          'cdse': 107,
#          'access': 107,
#          'goaligrnt': 106,
#          'algorithmic': 106,
#          'noyce': 105,
#          'sociology': 105,
#          'language': 105,
#          'animal': 105,
#          'quantitative': 105,
#          'experiment': 104,
#          'urban': 104,
#          'performance': 104,
#          'practice': 103,
#          'property': 103,
#          'cyberphysical': 103,
#          'dmr': 103,
#          'monitoring': 103,
#          'wave': 103,
#          'rsrch': 103,
#          'inference': 102,
#          'geochemistry': 102,
#          'history': 102,
#          'frontier': 102,
#          'cluster': 101,
#          'geometric': 99,
#          'extreme': 99,
#          'c': 99,
#          'active': 99,
#          'infection': 99,
#          'physiology': 99,
#          'psychology': 99,
#          'ccsscomms': 98,
#          'sen': 98,
#          'interface': 98,
#          'solar': 98,
#          'robert': 98,
#          'disease': 98,
#          'nuclear': 98,
#          'integrating': 98,
#          'factor': 98,
#          'adaptation': 97,
#          'electronics': 97,
#          'signal': 97,
#          'making': 96,
#          'pgm': 96,
#          'fluid': 96,
#          'professional': 95,
#          'supporting': 95,
#          'online': 95,
#          'window': 95,
#          'petrology': 94,
#          'advancing': 94,
#          'robot': 94,
#          'virtual': 94,
#          'hist': 93,
#          'nnanavigating': 93,
#          'opportunity': 93,
#          'assembly': 93,
#          'assessment': 93,
#          'formation': 93,
#          'policy': 92,
#          'univ': 92,
#          'travel': 92,
#          'systematics': 91,
#          'improve': 91,
#          'coronavirus': 91,
#          'architecture': 91,
#          'usgcrp': 90,
#          'exper': 90,
#          'biomaterials': 90,
#          'quantifying': 89,
#          'coupled': 89,
#          'agricultural': 89,
#          'int': 89,
#          'meteorology': 89,
#          'accelerator': 88,
#          'enveenvironmental': 88,
#          'amp': 88,
#          'transition': 88,
#          'epcnenergypowerctrlnetwrks': 88,
#          'shf': 88,
#          'time': 87,
#          'distributed': 87,
#          'public': 87,
#          'regional': 87,
#          'complexity': 87,
#          'tchr': 86,
#          'cost': 86,
#          'prediction': 85,
#          'realtime': 85,
#          'rural': 85,
#          'electronicphotonic': 85,
#          'enabling': 85,
#          'developmental': 85,
#          'transfer': 84,
#          'analytics': 84,
#          'hydrologic': 84,
#          'oiaoffice': 83,
#          'base': 83,
#          'act': 83,
#          'fundamental': 83,
#          'mat': 82,
#          'aisl': 82,
#          'csrcomputer': 82,
#          'wou': 82,
#          'postbaccalaureate': 81,
#          'mass': 81,
#          'problem': 81,
#          'pc': 81,
#          'spectrum': 80,
#          'knowledge': 80,
#          'collab': 80,
#          'scientific': 80,
#          'sustained': 80,
#          'harnessing': 80,
#          'low': 79,
#          'single': 79,
#          'cise': 78,
#          'pfipartnrships': 78,
#          'integrtv': 78,
#          'source': 77,
#          'scienc': 77,
#          'statistical': 77,
#          'relationship': 76,
#          'ci': 76,
#          'catalysis': 76,
#          'braincognitive': 76,
#          'astron': 76,
#          'success': 75,
#          'enhancing': 75,
#          'nonlinear': 75,
#          'dimension': 75,
#          'coordination': 75,
#          'event': 75,
#          'cnci': 75,
#          'f': 75,
#          'light': 75,
#          'extragalactic': 75,
#          'hybrid': 74,
#          'iii': 74,
#          'remote': 74,
#          'digital': 74,
#          'macromolecsupramolecnano': 74,
#          'big': 74,
#          'coastal': 74,
#          'th': 73,
#          'production': 73,
#          'feedback': 73,
#          'amo': 73,
#          'stress': 73,
#          'safety': 73,
#          'aspect': 72,
#          'cif': 72,
#          'enterprise': 72,
#          'mobility': 72,
#          'composite': 72,
#          'biophysics': 72,
#          'verification': 72,
#          'cssi': 72,
#          'datadriven': 72,
#          'industry': 71,
#          'cyberinfrastructurescience': 71,
#          'fast': 71,
#          'implication': 71,
#          'multiple': 70,
#          'infr': 70,
#          'accelerating': 70,
#          'influence': 70,
#          'reality': 69,
#          'fund': 69,
#          'natl': 69,
#          'fdfluid': 69,
#          'str': 69,
#          'electric': 69,
#          'characterization': 69,
#          'coord': 69,
#          'organization': 69,
#          'aerosol': 68,
#          'gas': 68,
#          'earthquake': 68,
#          'care': 68,
#          'thermal': 68,
#          'collaboration': 68,
#          'sedimentary': 68,
#          'laboratory': 68,
#          'living': 68,
#          'ice': 68,
#          'pattern': 68,
#          'cosmolo': 68,
#          'anthro': 67,
#          'geobiology': 67,
#          'geo': 67,
#          'electron': 67,
#          'sea': 67,
#          'tectonics': 67,
#          'envsenvironmtl': 67,
#          'de': 66,
#          'gene': 66,
#          'north': 66,
#          'geochem': 66,
#          'expanding': 66,
#          'nrinational': 66,
#          'initiati': 66,
#          'tropical': 66,
#          'physicsbroaden': 66,
#          'condition': 66,
#          'driver': 66,
#          'cyberinfr': 66,
#          'scientif': 66,
#          'automated': 66,
#          'cc': 66,
#          'precision': 66,
#          'optoelectronic': 66,
#          'specie': 65,
#          'ri': 65,
#          'educ': 65,
#          'algebra': 65,
#          'reaction': 65,
#          'magnetic': 65,
#          'beyond': 65,
#          'american': 65,
#          'includes': 65,
#          'membrane': 64,
#          'activit': 64,
#          'graph': 64,
#          'mitigation': 64,
#          'consequence': 64,
#          'wouwindows': 64,
#          'combinatorics': 64,
#          'component': 64,
#          'unallocated': 64,
#          'interfacial': 63,
#          'long': 63,
#          'vehicle': 63,
#          'cpscyberphysical': 63,
#          'coral': 63,
#          'geography': 63,
#          'treatment': 63,
#          'flux': 63,
#          'observation': 63,
#          'geomorphology': 63,
#          'physiol': 63,
#          'mechs': 63,
#          'itestinov': 62,
#          'stu': 62,
#          'teac': 62,
#          'edge': 62,
#          'mobile': 62,
#          'boundary': 62,
#          'strategy': 62,
#          'paleobiology': 62,
#          'mechanobiology': 62,
#          'mapping': 62,
#          'solution': 61,
#          'tissue': 61,
#          'supply': 61,
#          'integrat': 61,
#          'rsearch': 61,
#          'paleoclimate': 61,
#          'chemis': 61,
#          'cybersecurity': 61,
#          'learn': 61,
#          'cascritical': 60,
#          'autonomous': 60,
#          'among': 60,
#          'persistence': 60,
#          'recovery': 60,
#          'element': 60,
#          'implementation': 59,
#          'course': 59,
#          'forest': 59,
#          'memory': 59,
#          'eciengineering': 59,
#          'western': 59,
#          'ion': 59,
#          'delivery': 59,
#          'soil': 59,
#          'equation': 59,
#          'diverse': 59,
#          'pacific': 59,
#          'chembio': 59,
#          'spectroscopy': 59,
#          'modulation': 59,
#          'initiation': 58,
#          'programming': 58,
#          'regulation': 58,
#          'revolution': 58,
#          'dynam': 58,
#          'increasing': 58,
#          'retention': 57,
#          'changing': 57,
#          'fire': 57,
#          'fetfndtns': 57,
#          'mgi': 57,
#          'food': 56,
#          'effective': 56,
#          'cl': 56,
#          'isotope': 56,
#          'af': 56,
#          'b': 56,
#          'ansarctic': 56,
#          'efficiency': 56,
#          'outcome': 56,
#          'local': 56,
#          'bmmbbiomech': 56,
#          'balance': 56,
#          'southern': 56,
#          'optical': 56,
#          'augmented': 56,
#          'csforallcomputer': 56,
#          'mmwave': 55,
#          'mantle': 55,
#          'evaluation': 55,
#          'predictability': 55,
#          'ceramic': 55,
#          'lowtemp': 55,
#          'quality': 55,
#          'oxide': 55,
#          'pfitt': 55,
#          'cryptography': 55,
#          'next': 55,
#          'nitrogen': 55,
#          'institution': 55,
#          'algor': 55,
#          'creating': 54,
#          'develop': 54,
#          'drug': 54,
#          'improved': 54,
#          'preparation': 54,
#          'disability': 54,
#          'cloud': 54,
#          'leveraging': 54,
#          'sig': 54,
#          'radio': 54,
#          'heterogeneous': 54,
#          'representation': 54,
#          'context': 54,
#          'micro': 54,
#          'genomic': 54,
#          'intergovernmental': 54,
#          'st': 53,
#          'iucrcindustuniv': 53,
#          'ctr': 53,
#          'survey': 53,
#          'symbiosis': 53,
#          'engagement': 53,
#          'temperature': 53,
#          'improvement': 53,
#          'build': 53,
#          'cyberlearn': 53,
#          'engedengineering': 52,
#          'evaluating': 52,
#          'optimal': 52,
#          'interactive': 52,
#          'organism': 52,
#          'aeronomy': 52,
#          'enhance': 52,
#          'efri': 52,
#          'biotech': 52,
#          'highperformance': 52,
#          'postdoc': 52,
#          'ehr': 51,
#          'macrosysbio': 51,
#          'neonenabled': 51,
#          'computation': 51,
#          'spin': 51,
#          'immunity': 51,
#          'frg': 51,
#          'biochem': 51,
#          'methodology': 51,
#          'seismic': 51,
#          'leap': 51,
#          'level': 51,
#          'campus': 51,
#          'rii': 51,
#          'technique': 50,
#          'catalyst': 50,
#          'highly': 50,
#          'challenge': 50,
#          'topological': 50,
#          'understand': 50,
#          'landscape': 50,
#          'differential': 50,
#          'focused': 50,
#          'metallic': 50,
#          'resear': 50,
#          'inst': 50,
#          'additive': 50,
#          'mfg': 50,
#          'battery': 50,
#          'privacy': 49,
#          'stochastic': 49,
#          'inclusive': 49,
#          'scccivicpg': 49,
#          'intervention': 49,
#          'skill': 49,
#          'industryuniv': 49,
#          'gravity': 49,
#          'assessing': 49,
#          'longterm': 49,
#          'nanomanufacturing': 49,
#          'chs': 49,
#          'work': 49,
#          'biomed': 49,
#          'icb': 49,
#          'iibr': 49,
#          'toward': 48,
#          'liquid': 48,
#          'deformation': 48,
#          'landuse': 48,
#          'experimentatomic': 48,
#          'molecul': 48,
#          'visualization': 47,
#          'rfmicrowave': 47,
#          'coating': 47,
#          'spectrometer': 47,
#          'ttpthermal': 47,
#          'distribution': 47,
#          'intgstrat': 47,
#          'undst': 47,
#          'neurlcogn': 47,
#          'clbcareer': 47,
#          'identifying': 47,
#          'tracking': 47,
#          'neuroscience': 47,
#          'cdsemss': 47,
#          'ca': 46,
#          'mentoring': 46,
#          'designing': 46,
#          'pposs': 46,
#          'stability': 46,
#          'nsfbsf': 46,
#          'fmitf': 46,
#          'weather': 46,
#          'metrology': 46,
#          'variation': 46,
#          'reconstruction': 45,
#          'multimodal': 45,
#          'numerical': 45,
#          'layer': 45,
#          'partner': 45,
#          'iucrc': 45,
#          'culture': 45,
#          'alaska': 45,
#          'educational': 45,
#          'trace': 45,
#          'general': 45,
#          'symposium': 45,
#          'spatiotemporal': 45,
#          'cybertraining': 45,
#          'wind': 45,
#          'sharing': 45,
#          'pmpparticulmultiphaseprocess': 45,
#          'academic': 44,
#          'freq': 44,
#          'star': 44,
#          'microbiome': 44,
#          'reef': 44,
#          'part': 44,
#          'family': 44,
#          'echemselectrochemical': 44,
#          'virus': 44,
#          'electronic': 44,
#          'earthcube': 44,
#          'humanrobot': 44,
#          'spread': 44,
#          'grfp': 44,
#          'crystal': 43,
#          'region': 43,
#          'czocritical': 43,
#          'obsrvatories': 43,
#          'probability': 43,
#          'magnetospheric': 43,
#          'photonic': 43,
#          'coupling': 43,
#          'end': 43,
#          'enhanced': 43,
#          'world': 43,
#          'molecule': 43,
#          'mgt': 43,
#          'array': 43,
#          'measuring': 43,
#          'identification': 43,
#          'secondary': 43,
#          'identity': 43,
#          'progra': 42,
#          'viral': 42,
#          'vacuum': 42,
#          'oxygen': 42,
#          'youth': 42,
#          'fungal': 42,
#          'elementarysecondary': 42,
#          'robotic': 42,
#          'galactic': 42,
#          'icer': 42,
#          'laser': 42,
#          'scholar': 42,
#          'contact': 42,
#          'geotraces': 42,
#          'basic': 42,
#          'related': 42,
#          'growth': 42,
#          'host': 42,
#          'pressure': 42,
#          'hbcuexcellence': 41,
#          'product': 41,
#          'msprf': 41,
#          'mathscipdfel': 41,
#          'enhan': 41,
#          'tecp': 41,
#          'semiconductor': 41,
#          'technician': 41,
#          'woumma': 41,
#          'test': 41,
#          'stellar': 41,
#          'mbmechanobiology': 41,
#          'united': 41,
#          'principle': 41,
#          'auto': 41,
#          'enable': 41,
#          'near': 41,
#          'river': 41,
#          'era': 41,
#          'crisis': 40,
#          'commsensing': 40,
#          'nna': 40,
#          'sediment': 40,
#          'gap': 40,
#          'classroom': 40,
#          'nationl': 40,
#          'earthqk': 40,
#          'hzrd': 40,
#          'redct': 40,
#          'prg': 40,
#          'phys': 40,
#          'agreement': 40,
#          'partial': 40,
#          'alliance': 40,
#          'characterizing': 40,
#          'accelnet': 40,
#          'forum': 40,
#          'intl': 40,
#          'east': 40,
#          'internet': 40,
#          'examining': 40,
#          'increase': 40,
#          'emission': 40,
#          'tcn': 40,
#          'heat': 39,
#          'educationhuman': 39,
#          'resourcesoce': 39,
#          'soft': 39,
#          'innovative': 39,
#          'land': 39,
#          'nanomechanics': 39,
#          'nanostructure': 39,
#          'rahss': 39,
#          'nextgeneration': 39,
#          'cult': 39,
#          'curriculum': 39,
#          ...})

# %%
# To get word frequency for the a single object (experimental)
index_value = 12030
single_data_word_freq = get_word_frequency(processed_data, fields_to_frequency_count, single_object_index=index_value)

single_data_word_freq
# Out:
# Counter({'behavior': 2,
#          'involvement': 2,
#          'eavesdropping': 1,
#          'sound': 1,
#          'localization': 1,
#          'lesson': 1,
#          'small': 1,
#          'auditory': 1,
#          'specialist': 1,
#          'direct': 1,
#          'biological': 1,
#          'science': 1,
#          'division': 1,
#          'integrative': 1,
#          'organismal': 1,
#          'system': 1,
#          'animal': 1,
#          'minority': 1,
#          'bio': 1,
#          'undergraduate': 1,
#          'education': 1,
#          'graduate': 1,
#          'reu': 1,
#          'suppres': 1,
#          'exp': 1,
#          'ugrd': 1,
#          'supp': 1})
